# %%
# %cd drive/MyDrive/Colab\ Notebooks/GPU
# Out:
# /content/drive/MyDrive/Colab Notebooks/GPU

# %%
# !dir
# Out:
# code				Ex3_1.ipynb  Ex4_2.ipynb	 rodinia_3.1
# CUDA_Colab_bandwidthtest.ipynb	Ex3_2.ipynb  Ex4.ipynb		 sputniPIC-Hw3
# dataCPU				Ex3_3.ipynb  GPU_tutorial.ipynb
# Ex2_2.ipynb			Ex3_4.ipynb  project

# %%
# !nvidia-smi

# %%
# !cat /proc/cpuinfo && nproc --all

# %%
# !export CUDA_DEVICE_MAX_CONNECTIONS=32

# %%
# !nvcc code/lab3_ex1Stream.cu -g -arch sm_75 -o code/lab3_ex1Stream.o

# %%
# !./code/lab3_ex1Stream.o 33554432 32768
# Out:
# The input length is 33554432
# All correct!
# Total time: 57.782173

# %%
# !nvprof --output-profile ass4ex1ProfileV2.nvvp -f ./code/lab3_ex1Stream.o 33554432 32768
# Out:
# The input length is 33554432
# ==456== NVPROF is profiling process 456, command: ./code/lab3_ex1Stream.o 33554432 32768
# All correct!
# Total time: 61.009884==456== Generated result file: /content/drive/MyDrive/Colab Notebooks/GPU/ass4ex1ProfileV2.nvvp

# %%
# !cuda-gdb ./code/lab3_ex1Stream.o

# %%
# !chmod -X code/ex1Test.sh
# !bash code/ex1Test.sh
# Out:
# Running streamed addvec with seg size: 32
#
# With input length 4096
# The input length is 4096
# All correct!
# Total time: 0.894070
#
# With input length 16384
# The input length is 16384
# All correct!
# Total time: 3.426790
#
# With input length 65536
# The input length is 65536
# All correct!
# Total time: 13.227940
#
# With input length 131070
# The input length is 131070
# All correct!
# Total time: 28.254986
#
# With input length 262144
# The input length is 262144
# All correct!
# Total time: 54.411173
#
# With input length 1048576
# The input length is 1048576
# All correct!
# Total time: 222.045898
#
#
#
# Running streamed addvec with seg size: 256
#
# With input length 4096
# The input length is 4096
# All correct!
# Total time: 0.170946
#
# With input length 16384
# The input length is 16384
# All correct!
# Total time: 0.551939
#
# With input length 65536
# The input length is 65536
# All correct!
# Total time: 1.936197
#
# With input length 131070
# ...

# %%
# Out:
# /bin/bash: ./code/ex1Test.sh: /bin/bash: bad interpreter: Permission denied
