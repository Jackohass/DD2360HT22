# %%
# %cd drive/MyDrive/Colab\ Notebooks/GPU
# Out:
# /content/drive/MyDrive/Colab Notebooks/GPU

# %%
# !ls

# %%
# !nvidia-smi
# Out:
# Sun Jan  8 19:36:38 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P0    28W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !cat /proc/cpuinfo && nproc --all

# %%
# !nvcc code/lab4-ex4.cu -arch sm_75 -lcublas -lcusparse -o code/lab4-ex4.o

# %%
# !./code/lab4-ex4.o 200000 200000
# Out:
# The X dimension of the grid is 200000
# The number of time steps to perform is 200000
# Timing - Allocating device memory. 		Elasped 178613 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 3711 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2316 microseconds
# Timing - Initializing memory on the host. 		Elasped 296 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 407 microseconds
# The relative error of the approximation is 0.997679
# Total time: 0.000000 s, FLOPs: 239.997600, FLOPS: inf

# %%
# !nvprof -f ./code/lab4-ex4.o 200000 200000
# Out:
# The X dimension of the grid is 200000
# The number of time steps to perform is 200000
# ==1009== NVPROF is profiling process 1009, command: ./code/lab4-ex4.o 200000 200000
# Timing - Allocating device memory. 		Elasped 400949 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 4447 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2315 microseconds
# Timing - Initializing memory on the host. 		Elasped 314 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 448 microseconds
# The relative error of the approximation is 0.997679
# Total time: 0.000000 s, FLOPs: 239.997600, FLOPS: inf
# ==1009== Profiling application: ./code/lab4-ex4.o 200000 200000
# ==1009== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
# ...

# %%
# !bash code/lab4ex4Test.sh
# Out:
# Running heat calc with dimx: 128
#
# With nstep: 100
# The X dimension of the grid is 128
# The number of time steps to perform is 100
# The relative error of the approximation is 0.911439
# Total time: 0.002884 s, FLOPs: 0.000076, FLOPS: 0.026214
#
#
# With nstep: 200
# The X dimension of the grid is 128
# The number of time steps to perform is 200
# The relative error of the approximation is 0.874380
# Total time: 0.005874 s, FLOPs: 0.000151, FLOPS: 0.025741
#
#
# With nstep: 500
# The X dimension of the grid is 128
# The number of time steps to perform is 500
# The relative error of the approximation is 0.796206
# Total time: 0.014255 s, FLOPs: 0.000378, FLOPS: 0.026517
#
#
# With nstep: 1000
# The X dimension of the grid is 128
# The number of time steps to perform is 1000
# The relative error of the approximation is 0.698903
# Total time: 0.027586 s, FLOPs: 0.000756, FLOPS: 0.027405
#
#
# With nstep: 2000
# The X dimension of the grid is 128
# ...
