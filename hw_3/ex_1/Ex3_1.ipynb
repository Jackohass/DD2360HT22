# %%
# %cd drive/MyDrive/Colab\ Notebooks/GPU
# Out:
# /content/drive/MyDrive/Colab Notebooks/GPU

# %%
# !ls
# Out:
# code				Ex2_2.ipynb  Ex4.ipynb		 rodinia_3.1
# CUDA_Colab_bandwidthtest.ipynb	Ex3_1.ipynb  GPU_tutorial.ipynb

# %%
# !nvidia-smi
# Out:
# Tue Dec 13 11:46:22 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P0    32W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !cat /proc/cpuinfo && nproc --all
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.206
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# ...

# %%
# !nvcc code/lab3_ex1.cu -arch sm_75 -o code/lab3_ex1.o

# %%
# !./code/lab3_ex1.o 1024
# Out:
# The input length is 1024
# Device : Tesla T4
# All correct!
# H->D: 0.032902 ms, D->H: 0.020027 ms, Kernel: 0.030041 ms

# %%
# !./code/lab3_ex1.o 131070
# Out:
# The input length is 131070
# Device : Tesla T4
# All correct!
# H->D: 0.583887 ms, D->H: 0.754118 ms, Kernel: 0.112057 ms

# %%
# !./code/lab3_ex1.o 256
# Out:
# The input length is 256
# Device : Tesla T4
# All correct!
# H->D: 0.025988 ms, D->H: 0.015974 ms, Kernel: 0.021935 ms

# %%
# !./code/lab3_ex1.o 4096
# Out:
# The input length is 4096
# Device : Tesla T4
# All correct!
# H->D: 0.051975 ms, D->H: 0.036955 ms, Kernel: 0.023127 ms

# %%
# !./code/lab3_ex1.o 16384
# Out:
# The input length is 16384
# Device : Tesla T4
# All correct!
# H->D: 0.092983 ms, D->H: 0.101089 ms, Kernel: 0.027895 ms

# %%
# !./code/lab3_ex1.o 65536
# Out:
# The input length is 65536
# Device : Tesla T4
# All correct!
# H->D: 0.283957 ms, D->H: 0.375986 ms, Kernel: 0.067949 ms

# %%
# !./code/lab3_ex1.o 262144
# Out:
# The input length is 262144
# Device : Tesla T4
# All correct!
# H->D: 0.977039 ms, D->H: 1.379013 ms, Kernel: 0.121117 ms

# %%
# !./code/lab3_ex1.o 1048576
# Out:
# The input length is 1048576
# Device : Tesla T4
# All correct!
# H->D: 3.677130 ms, D->H: 5.317926 ms, Kernel: 0.191927 ms

# %%
# !nv-nsight-cu-cli ./code/lab3_ex1.o 1024
# Out:
# The input length is 1024
# ==PROF== Connected to process 2146 (/content/drive/MyDrive/Colab Notebooks/GPU/code/lab3_ex1.o)
# Device : Tesla T4
# ==PROF== Profiling "vecAdd" - 1: 0%....50%....100% - 8 passes
# All correct!
# H->D: 0.046015 ms, D->H: 0.057936 ms, Kernel: 878.580093 ms==PROF== Disconnected from process 2146
# [2146] lab3_ex1.o@127.0.0.1
#   vecAdd(double*, double*, double*, int), 2022-Dec-13 12:40:46, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           4.91
#     SM Frequency                                                             cycle/usecond                         575.23
#     Elapsed Cycles                                                                   cycle                          3,001
# ...

# %%
# !nv-nsight-cu-cli ./code/lab3_ex1.o 131070
# Out:
# The input length is 131070
# ==PROF== Connected to process 2172 (/content/drive/MyDrive/Colab Notebooks/GPU/code/lab3_ex1.o)
# Device : Tesla T4
# ==PROF== Profiling "vecAdd" - 1: 0%....50%....100% - 8 passes
# All correct!
# H->D: 0.568151 ms, D->H: 0.832081 ms, Kernel: 747.654915 ms==PROF== Disconnected from process 2172
# [2172] lab3_ex1.o@127.0.0.1
#   vecAdd(double*, double*, double*, int), 2022-Dec-13 12:41:11, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           4.96
#     SM Frequency                                                             cycle/usecond                         581.25
#     Elapsed Cycles                                                                   cycle                          8,188
# ...
