# %%
# %cd drive/MyDrive/Colab\ Notebooks/GPU
# Out:
# /content/drive/MyDrive/Colab Notebooks/GPU

# %%
# !ls
# Out:
# code				Ex2_2.ipynb  Ex4.ipynb
# CUDA_Colab_bandwidthtest.ipynb	Ex3_1.ipynb  GPU_tutorial.ipynb
# data				Ex3_2.ipynb  rodinia_3.1

# %%
# !nvidia-smi
# Out:
# Tue Dec 13 11:46:22 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P0    32W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !cat /proc/cpuinfo && nproc --all
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.206
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# ...

# %%
# !nvcc code/lab3_ex2.cu -arch sm_75 -o code/lab3_ex2.o

# %%
# !./code/lab3_ex2.o 128 128 128
# Out:
# Streaming output truncated to the last 5000 lines.
# Index: (8, 9), Ref: 37.114277, GPU: 37.114281, Diff: 0.000004
# Index: (21, 9), Ref: 31.923895, GPU: 31.923893, Diff: 0.000002
# Index: (31, 9), Ref: 35.549763, GPU: 35.549759, Diff: 0.000004
# Index: (34, 9), Ref: 37.213474, GPU: 37.213470, Diff: 0.000004
# Index: (47, 9), Ref: 35.163929, GPU: 35.163933, Diff: 0.000004
# Index: (48, 9), Ref: 35.786942, GPU: 35.786949, Diff: 0.000008
# Index: (49, 9), Ref: 34.765911, GPU: 34.765907, Diff: 0.000004
# Index: (50, 9), Ref: 31.735264, GPU: 31.735266, Diff: 0.000002
# Index: (51, 9), Ref: 32.514393, GPU: 32.514389, Diff: 0.000004
# Index: (57, 9), Ref: 37.201862, GPU: 37.201866, Diff: 0.000004
# Index: (58, 9), Ref: 36.441296, GPU: 36.441292, Diff: 0.000004
# Index: (60, 9), Ref: 35.003204, GPU: 35.003208, Diff: 0.000004
# Index: (68, 9), Ref: 35.494587, GPU: 35.494591, Diff: 0.000004
# Index: (71, 9), Ref: 35.350700, GPU: 35.350697, Diff: 0.000004
# ...

# %%
# !./code/lab3_ex2.o 511 1023 4094
# Out:
# Input matrix dim (511 x 1023) (1023 x 4094) (511 x 4094)
# Device : Tesla T4
# All correct!
# H->D: 4.124880 ms, D->H: 5.281925 ms, Kernel: 15.073061 ms

# %%
# !./code/lab3_ex2.o 256 512 2048
# Out:
# Input matrix dim (256 x 512) (512 x 2048) (256 x 2048)
# Device : Tesla T4
# All correct!
# H->D: 1.085043 ms, D->H: 1.433134 ms, Kernel: 1.896858 ms

# %%
# !./code/lab3_ex2.o 320 640 2560
# Out:
# Input matrix dim (320 x 640) (640 x 2560) (320 x 2560)
# Device : Tesla T4
# All correct!
# H->D: 1.637936 ms, D->H: 2.096176 ms, Kernel: 3.662825 ms

# %%
# !./code/lab3_ex2.o 384 768 3072
# Out:
# Input matrix dim (384 x 768) (768 x 3072) (384 x 3072)
# Device : Tesla T4
# All correct!
# H->D: 2.317905 ms, D->H: 3.038883 ms, Kernel: 6.329060 ms

# %%
# !./code/lab3_ex2.o 448 896 3584
# Out:
# Input matrix dim (448 x 896) (896 x 3584) (448 x 3584)
# Device : Tesla T4
# All correct!
# H->D: 3.050089 ms, D->H: 4.064083 ms, Kernel: 10.015965 ms

# %%
# !./code/lab3_ex2.o 128 256 1024
# Out:
# Input matrix dim (128 x 256) (256 x 1024) (128 x 1024)
# Device : Tesla T4
# All correct!
# H->D: 0.281096 ms, D->H: 0.383854 ms, Kernel: 0.368118 ms

# %%
# !./code/lab3_ex2.o 192 384 1536
# Out:
# Input matrix dim (192 x 384) (384 x 1536) (192 x 1536)
# Device : Tesla T4
# All correct!
# H->D: 0.617027 ms, D->H: 0.896931 ms, Kernel: 0.862122 ms

# %%
# !nv-nsight-cu-cli ./code/lab3_ex2.o 128 128 128

# %%
# !nv-nsight-cu-cli ./code/lab3_ex2.o 511 1023 4094
# Out:
# Input matrix dim (511 x 1023) (1023 x 4094) (511 x 4094)
# ==PROF== Connected to process 1636 (/content/drive/MyDrive/Colab Notebooks/GPU/code/lab3_ex2.o)
# Device : Tesla T4
# ==PROF== Profiling "gemm" - 1: 0%....50%....100% - 8 passes
# All correct!
# H->D: 8.380890 ms, D->H: 11.354923 ms, Kernel: 1048.578978 ms==PROF== Disconnected from process 1636
# [1636] lab3_ex2.o@127.0.0.1
#   gemm(double*, double*, double*, int, int, int, int), 2022-Dec-13 15:45:51, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           5.00
#     SM Frequency                                                             cycle/usecond                         584.90
# ...
