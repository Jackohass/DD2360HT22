# %%
# %cd drive/MyDrive/Colab\ Notebooks/GPU
# Out:
# /content/drive/MyDrive/Colab Notebooks/GPU

# %%
# !dir
# Out:
#  Volume in drive H is j
#  Volume Serial Number is 807C-6F57
#
#  Directory of H:\
#
# 2018-08-02  10:42    <DIR>          .
# 2022-11-17  16:21    <DIR>          ..
# 2018-08-02  10:42    <DIR>          appdata
#                0 File(s)              0 bytes
#                3 Dir(s)   3ÿ212ÿ931ÿ072 bytes free

# %%
# !nvidia-smi
# Out:
# Thu Dec 15 21:31:17 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    25W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !cat /proc/cpuinfo && nproc --all
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.206
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# ...

# %%
# !nvcc code/lab3_ex3.cu -arch sm_75 -o code/lab3_ex3.o
# Out:
# 'nvcc' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !./code/lab3_ex3.o 3072
# Out:
# The input length is 3072
# Device : Tesla T4
# All correct!
# CPU: 0.035048 ms, H->D: 0.042915 ms, D->H: 0.028133 ms, Kernel: 0.108957 ms, naive

# %%
# !./code/lab3_ex3.o 98304
# Out:
# The input length is 98304
# Device : Tesla T4
# All correct!
# CPU: 0.566959 ms, H->D: 0.106096 ms, D->H: 0.045061 ms, Kernel: 0.117064 ms

# %%
# !./code/lab3_ex3.o 6144
# Out:
# The input length is 6144
# Device : Tesla T4
# All correct!
# CPU: 0.054121 ms, H->D: 0.058174 ms, D->H: 0.025988 ms, Kernel: 0.088930 ms, naive

# %%
# !./code/lab3_ex3.o 3145728
# Out:
# The input length is 3145728
# Device : Tesla T4
# All correct!
# CPU: 7.699966 ms, H->D: 2.646923 ms, D->H: 0.034094 ms, Kernel: 3.844976 ms, naive

# %%
# !./code/lab3_ex3.o 6291456
# Out:
# The input length is 6291456
# Device : Tesla T4
# All correct!
# CPU: 13.886929 ms, H->D: 5.479097 ms, D->H: 0.032902 ms, Kernel: 7.597923 ms, naive

# %%
# !./code/lab3_ex3.o 516096
# Out:
# The input length is 516096
# Device : Tesla T4
# All correct!
# CPU: 2.184153 ms, H->D: 0.519991 ms, D->H: 0.029802 ms, Kernel: 0.733137 ms, naive

# %%
# !./code/lab3_ex3.o 786432
# Out:
# The input length is 786432
# Device : Tesla T4
# All correct!
# CPU: 3.042936 ms, H->D: 0.699997 ms, D->H: 0.030994 ms, Kernel: 1.073122 ms, naive

# %%
# !./code/lab3_ex3.o 1572864
# Out:
# The input length is 1572864
# Device : Tesla T4
# All correct!
# CPU: 4.613876 ms, H->D: 1.405954 ms, D->H: 0.032902 ms, Kernel: 1.984119 ms, naive

# %%
# !./code/lab3_ex3.o 1610612736
# Out:
# The input length is 1610612736
# tcmalloc: large alloc 6442450944 bytes == 0x55ac605f2000 @  0x7fcce3bc71e7 0x55ac5e607868 0x7fcce285ac87 0x55ac5e6075aa
# Device : Tesla T4
# All correct!
# CPU: 3221.554995 ms, H->D: 1362.800121 ms, D->H: 0.047922 ms, Kernel: 851.433039 ms, naive

# %%
# !./code/lab3_ex3.o 1024
# Out:
# The input length is 1026
# Device : Tesla T4
# All correct!
# CPU: 0.023127 ms, H->D: 0.092983 ms, D->H: 0.029087 ms, Kernel: 0.082016 ms

# %%
# !nv-nsight-cu-cli ./code/lab3_ex3.o 1610612736
# Out:
# The input length is 1610612736
# tcmalloc: large alloc 6442450944 bytes == 0x56016b2de000 @  0x7f6814d031e7 0x560169007868 0x7f680ff26c87 0x5601690075aa
# ==PROF== Connected to process 2385 (/content/drive/MyDrive/Colab Notebooks/GPU/code/lab3_ex3.o)
# Device : Tesla T4
# ==PROF== Profiling "histogram_kernelNaive" - 1: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convert_kernel" - 2: 0%....50%....100% - 8 passes
# All correct!
# CPU: 3218.863964 ms, H->D: 1343.069077 ms, D->H: 0.061989 ms, Kernel: 17148.153067 ms, naive
# ==PROF== Disconnected from process 2385
# [2385] lab3_ex3.o@127.0.0.1
#   histogram_kernelNaive(unsigned int*, unsigned int*, unsigned int, unsigned int), 2022-Dec-15 23:37:27, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
# ...

# %%
# !nv-nsight-cu-cli ./code/lab3_ex3.o 3072
# Out:
# The input length is 3072
# ==PROF== Connected to process 2075 (/content/drive/MyDrive/Colab Notebooks/GPU/code/lab3_ex3.o)
# Device : Tesla T4
# ==PROF== Profiling "histogram_kernel3" - 1: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convert_kernel" - 2: 0%....50%....100% - 8 passes
# All correct!
# CPU: 0.036001 ms, H->D: 0.036001 ms, D->H: 0.075817 ms, Kernel: 1465.819120 ms==PROF== Disconnected from process 2075
# [2075] lab3_ex3.o@127.0.0.1
#   histogram_kernel3(unsigned int*, unsigned int*, unsigned int, unsigned int), 2022-Dec-15 23:22:01, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           4.98
#     SM Frequency                                                             cycle/usecond                         582.85
# ...

# %%
# !nv-nsight-cu-cli ./code/lab3_ex3.o 1024
# Out:
# The input length is 1026
# ==PROF== Connected to process 3252 (/content/drive/MyDrive/Colab Notebooks/GPU/code/lab3_ex3.o)
# Device : Tesla T4
# ==PROF== Profiling "histogram_kernel3" - 1: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convert_kernel" - 2: 0%....50%....100% - 8 passes
# All correct!
# CPU: 0.025988 ms, H->D: 0.060081 ms, D->H: 0.053167 ms, Kernel: 1144.074917 ms
# ==PROF== Disconnected from process 3252
# [3252] lab3_ex3.o@127.0.0.1
#   histogram_kernel3(unsigned int*, unsigned int*, unsigned int, unsigned int), 2022-Dec-16 00:18:07, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           4.97
#     SM Frequency                                                             cycle/usecond                         582.53
# ...
